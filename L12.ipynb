# %%
import numpy as np
import pandas as pd
import sklearn as skl
import matplotlib
from sklearn import svm
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-7609fac3b35e> in <module>
#       2 import pandas as pd
#       3 import sklearn as skl
# ----> 4 help[read.csv]
#
# NameError: name 'read' is not defined

# %%
data = pd.read_csv("african_crises.csv")

# %%
# Out:
#       case  cc3   country  year  systemic_crisis    exch_usd  \
# 0        1  DZA   Algeria  1870                1    0.052264
# 1        1  DZA   Algeria  1871                0    0.052798
# 2        1  DZA   Algeria  1872                0    0.052274
# 3        1  DZA   Algeria  1873                0    0.051680
# 4        1  DZA   Algeria  1874                0    0.051308
# ...    ...  ...       ...   ...              ...         ...
# 1054    70  ZWE  Zimbabwe  2009                1  354.800000
# 1055    70  ZWE  Zimbabwe  2010                0  378.200000
# 1056    70  ZWE  Zimbabwe  2011                0  361.900000
# 1057    70  ZWE  Zimbabwe  2012                0  361.900000
# 1058    70  ZWE  Zimbabwe  2013                0  361.900000
#
#       domestic_debt_in_default  sovereign_external_debt_default  \
# 0                            0                                0
# 1                            0                                0
# ...

# %%
np.unique(data["country"].values, return_counts=True)
# Out:
# (array(['Algeria', 'Angola', 'Central African Republic', 'Egypt',
#         'Ivory Coast', 'Kenya', 'Mauritius', 'Morocco', 'Nigeria',
#         'South Africa', 'Tunisia', 'Zambia', 'Zimbabwe'], dtype=object),
#  array([ 85,  77,  58, 155,  63,  67,  68,  75,  60, 114,  75,  72,  90],
#        dtype=int64))

# %%
Morocco = data[data.country == "Morocco"]
Zimbabve = data[data.country == "Zimbabve"]
Algeria = data[data.country == "Algeria"]
Angola = data[data.country == "Angola"]
Central_African_Republic = data[data.country == "Central African Republic"]
Ivory_Coast = data[data.country == "Ivory Coast"]
Egypt = data[data.country == "Egypt"]
Kenya = data[data.country == "Kenya"]
Mauritius = data[data.country == "Mauritius"]
Nigeria = data[data.country == "Nigeria"]
South_Africa = data[data.country == "South Africa"]
Tunisia = data[data.country == "Tunisia"]
Zambia = data[data.country == "Zambia"]
Zimbabve = data[data.country == "Zimbabve"]
country, cnt = np.unique(data["systemic_crisis"].values, return_counts = True)

# %%
cnt
# Out:
# array([977,  82], dtype=int64)

# %%
Morocco = data[data.country == "Morocco"]
Morocco
# Out:
#      case  cc3  country  year  systemic_crisis  exch_usd  \
# 573    40  MAR  Morocco  1940                0    0.9170
# 574    40  MAR  Morocco  1941                0    0.9170
# 575    40  MAR  Morocco  1942                0    0.7500
# 576    40  MAR  Morocco  1943                0    0.5000
# 577    40  MAR  Morocco  1944                0    0.5674
# ..    ...  ...      ...   ...              ...       ...
# 643    40  MAR  Morocco  2010                0    8.3569
# 644    40  MAR  Morocco  2011                0    8.5772
# 645    40  MAR  Morocco  2012                0    8.4335
# 646    40  MAR  Morocco  2013                0    8.1500
# 647    40  MAR  Morocco  2014                0    8.8200
#
#      domestic_debt_in_default  sovereign_external_debt_default  \
# 573                         0                                0
# 574                         0                                0
# 575                         0                                0
# ...

# %%
Morocco.head(6)
# Out:
#      case  cc3  country  year  systemic_crisis  exch_usd  \
# 573    40  MAR  Morocco  1940                0    0.9170
# 574    40  MAR  Morocco  1941                0    0.9170
# 575    40  MAR  Morocco  1942                0    0.7500
# 576    40  MAR  Morocco  1943                0    0.5000
# 577    40  MAR  Morocco  1944                0    0.5674
# 578    40  MAR  Morocco  1945                0    0.5657
#
#      domestic_debt_in_default  sovereign_external_debt_default  \
# 573                         0                                0
# 574                         0                                0
# 575                         0                                0
# 576                         0                                0
# 577                         0                                0
# 578                         0                                0
#
#      gdp_weighted_default  inflation_annual_cpi  independence  \
# ...

# %%
Morocco = data[data.country == "Morocco"]
Zimbabve = data[data.country == "Zimbabve"]
Algeria = data[data.country == "Algeria"]
Angola = data[data.country == "Angola"]
Central_African_Republic = data[data.country == "Central African Republic"]
Ivory_Coast = data[data.country == "Ivory Coast"]
Egypt = data[data.country == "Egypt"]
Kenya = data[data.country == "Kenya"]
Mauritius = data[data.country == "Mauritius"]
Nigeria = data[data.country == "Nigeria"]
South_Africa = data[data.country == "South Africa"]
Tunisia = data[data.country == "Tunisia"]
Zambia = data[data.country == "Zambia"]
Zimbabve = data[data.country == "Zimbabve"]
country, cnt = np.unique(data["systemic_crisis"].values, return_counts = True)
# Out:
# array([0, 1], dtype=int64)

# %%
country, cnt = np.unique(data["systemic_crisis"].values, return_counts = True)

# %%
country
# Out:
# array([0, 1], dtype=int64)

# %%
cnt
# Out:
# array([977,  82], dtype=int64)
